# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('all/train.csv')

# %% [markdown]
# Core Data fields
#
#     - Id - a unique identifier for each row.
#     - Target - the target is an ordinal variable indicating groups of income levels.
#         - 1 = extreme poverty
#         - 2 = moderate poverty
#         - 3 = vulnerable households
#         - 4 = non vulnerable households
#     - idhogar - this is a unique identifier for each household. This can be used to create household-wide features, etc. All rows in a given household will have a matching value for this identifier.
#     - parentesco1 - indicates if this person is the head of the household.
# *This data contains 142 total columns.
#
# - v2a1, Monthly rent payment
# - v14a, =1 has bathroom in the household
# - refrig, =1 if the household has refrigerator
# - v18q, owns a tablet
# - v18q1, number of tablets household owns
# - computer, =1 if the household has notebook or desktop computer
# - television, =1 if the household has TV
# - mobilephone, =1 if mobile phone
# - qmobilephone, # of mobile phones
# - age, Age in years
#
# --------------------------------
# - escolari, years of schooling
# - rez_esc, Years behind in school
#
# --------------------------------
# - r4h1, Males younger than 12 years of age
# - r4h2, Males 12 years of age and older
# - r4h3, Total males in the household
# --------------------------------
# - r4m1, Females younger than 12 years of age
# - r4m2, Females 12 years of age and older
# - r4m3, Total females in the household
# --------------------------------
# - r4t1, persons younger than 12 years of age
# - r4t2, persons 12 years of age and older
# - r4t3, Total persons in the household
#
# --------------------------------
# - tamhog, size of the household
# - tamviv, number of persons living in the household
# - hhsize, household size
# - rooms,  number of all rooms in the house
# - hacapo, =1 Overcrowding by rooms
# - hacdor, =1 Overcrowding by bedrooms
# - bedrooms, number of bedrooms
# - overcrowding, # persons per room
# --------------------------------
# - paredblolad, =1 if predominant material on the outside wall is block or brick
# - paredzocalo, "=1 if predominant material on the outside wall is socket (wood,  zinc or absbesto"
# - paredpreb, =1 if predominant material on the outside wall is prefabricated or cement
# - pareddes, =1 if predominant material on the outside wall is waste material
# - paredmad, =1 if predominant material on the outside wall is wood
# - paredzinc, =1 if predominant material on the outside wall is zink
# - paredfibras, =1 if predominant material on the outside wall is natural fibers
# - paredother, =1 if predominant material on the outside wall is other
# --------------------------------
# - pisomoscer, "=1 if predominant material on the floor is mosaic,  ceramic,  terrazo"
# - pisocemento, =1 if predominant material on the floor is cement
# - pisoother, =1 if predominant material on the floor is other
# - pisonatur, =1 if predominant material on the floor is  natural material
# - pisonotiene, =1 if no floor at the household
# - pisomadera, =1 if predominant material on the floor is wood
# --------------------------------
# - techozinc, =1 if predominant material on the roof is metal foil or zink
# - techoentrepiso, "=1 if predominant material on the roof is fiber cement,  mezzanine "
# - techocane, =1 if predominant material on the roof is natural fibers
# - techootro, =1 if predominant material on the roof is other
# --------------------------------
# - cielorazo, =1 if the house has ceiling
# --------------------------------
# - abastaguadentro, =1 if water provision inside the dwelling
# - abastaguafuera, =1 if water provision outside the dwelling
# - abastaguano, =1 if no water provision
# --------------------------------
# - public, "=1 electricity from CNFL,  ICE,  ESPH/JASEC"
# - planpri, =1 electricity from private plant
# - noelec, =1 no electricity in the dwelling
# - coopele, =1 electricity from cooperative
# --------------------------------
# - sanitario1, =1 no toilet in the dwelling
# - sanitario2, =1 toilet connected to sewer or cesspool
# - sanitario3, =1 toilet connected to  septic tank
# - sanitario5, =1 toilet connected to black hole or letrine
# - sanitario6, =1 toilet connected to other system
# --------------------------------
# - energcocinar1, =1 no main source of energy used for cooking (no kitchen)
# - energcocinar2, =1 main source of energy used for cooking electricity
# - energcocinar3, =1 main source of energy used for cooking gas
# - energcocinar4, =1 main source of energy used for cooking wood charcoal
# --------------------------------
# - elimbasu1, =1 if rubbish disposal mainly by tanker truck
# - elimbasu2, =1 if rubbish disposal mainly by botan hollow or buried
# - elimbasu3, =1 if rubbish disposal mainly by burning
# - elimbasu4, =1 if rubbish disposal mainly by throwing in an unoccupied space
# - elimbasu5, "=1 if rubbish disposal mainly by throwing in river,  creek or sea"
# - elimbasu6, =1 if rubbish disposal mainly other
# --------------------------------
# - epared1, =1 if walls are bad
# - epared2, =1 if walls are regular
# - epared3, =1 if walls are good
# --------------------------------
# - etecho1, =1 if roof are bad
# - etecho2, =1 if roof are regular
# - etecho3, =1 if roof are good
# --------------------------------
# - eviv1, =1 if floor are bad
# - eviv2, =1 if floor are regular
# - eviv3, =1 if floor are good
# --------------------------------
# - dis, =1 if disable person
# - male, =1 if male
# - female, =1 if female
# --------------------------------
# - estadocivil1, =1 if less than 10 years old
# - estadocivil2, =1 if free or coupled uunion
# - estadocivil3, =1 if married
# - estadocivil4, =1 if divorced
# - estadocivil5, =1 if separated
# - estadocivil6, =1 if widow/er
# - estadocivil7, =1 if single
# --------------------------------
# - parentesco1, =1 if household head
# - parentesco2, =1 if spouse/partner
# - parentesco3, =1 if son/doughter
# - parentesco4, =1 if stepson/doughter
# - parentesco5, =1 if son/doughter in law
# - parentesco6, =1 if grandson/doughter
# - parentesco7, =1 if mother/father
# - parentesco8, =1 if father/mother in law
# - parentesco9, =1 if brother/sister
# - parentesco10, =1 if brother/sister in law
# - parentesco11, =1 if other family member
# - parentesco12, =1 if other non family member
# --------------------------------
# - idhogar, Household level identifier
# --------------------------------
# - hogar_nin, Number of children 0 to 19 in household
# - hogar_adul, Number of adults in household
# - hogar_mayor, # of individuals 65+ in the household
# - hogar_total, # of total individuals in the household
# --------------------------------
# - dependency, Dependency rate, calculated = (number of members of the household younger than 19 or older than 64)/(number of member of household between 19 and 64)
# --------------------------------
# - edjefe, years of education of male head of household, based on the interaction of escolari (years of education), head of household and gender, yes=1 and no=0
# - edjefa, years of education of female head of household, based on the interaction of escolari (years of education), - head of household and gender, yes=1 and no=0
# - meaneduc,average years of education for adults (18+)
# --------------------------------
# - instlevel1, =1 no level of education
# - instlevel2, =1 incomplete primary
# - instlevel3, =1 complete primary
# - instlevel4, =1 incomplete academic secondary level
# - instlevel5, =1 complete academic secondary level
# - instlevel6, =1 incomplete technical secondary level
# - instlevel7, =1 complete technical secondary level
# - instlevel8, =1 undergraduate and higher education
# - instlevel9, =1 postgraduate higher education
# --------------------------------
# - tipovivi1, =1 own and fully paid house
# - tipovivi2, "=1 own,  paying in installments"
# - tipovivi3, =1 rented
# - tipovivi4, =1 precarious
# - tipovivi5, "=1 other(assigned,  borrowed)"
# --------------------------------
# - lugar1, =1 region Central
# - lugar2, =1 region Chorotega
# - lugar3, =1 region Pacifico central
# - lugar4, =1 region Brunca
# - lugar5, =1 region Huetar Atlantica
# - lugar6, =1 region Huetar Norte
# --------------------------------
# - area1, =1 zona urbana
# - area2, =2 zona rural

# %% [markdown]
# # I.) Data Correction:

# %% [markdown]
# ### a.) Mishandling of Data
#     - There are three houses (idhogar) with no adults reported
#     - Depedency ratios are incorrect [(hogar_nin + hogar_mayor) / hogar_adul]
#     - Total people in a house are also incorrect: only reflect children to adult ratio and some ratios are
#     exagerated such that they would not be replicatable
#
# Resolution: Dropped the three houses (idhogar) because I would not be able to make corrections for the dependency and total house (hogar_total)

# %%
df[df.hogar_adul == 0].iloc[:,94:114]
# Out:
#       parentesco12    idhogar  hogar_nin  hogar_adul  hogar_mayor  \
# 1291             0  1b31fd159          1           0            0
# 1840             0  a874b7ce7          2           0            0
# 1841             0  a874b7ce7          2           0            0
# 2049             0  faaebf71a          2           0            0
# 2050             1  faaebf71a          2           0            0
#
#       hogar_total dependency edjefe edjefa  meaneduc  instlevel1  instlevel2  \
# 1291            1          8     no     10       NaN           0           0
# 1840            2          8      4     no       NaN           0           0
# 1841            2          8      4     no       NaN           0           1
# 2049            2          8     12     no       NaN           0           0
# 2050            2          8     12     no       NaN           0           0
#
#       instlevel3  instlevel4  instlevel5  instlevel6  instlevel7  instlevel8  \
# ...

# %%
df[df.dependency == '8'].iloc[:,94:114].head(10)
# Out:
#      parentesco12    idhogar  hogar_nin  hogar_adul  hogar_mayor  hogar_total  \
# 1               0  0e5d7a658          0           1            1            1
# 2               0  2c7317ea8          0           1            1            1
# 21              0  ec0e8edce          0           2            2            2
# 22              0  ec0e8edce          0           2            2            2
# 45              0  9b084b23d          0           2            2            2
# 46              0  9b084b23d          0           2            2            2
# 58              0  09a26c158          0           1            1            1
# 64              0  d9281c805          0           1            1            1
# 92              0  0b7ee52ff          0           1            1            1
# 107             0  ed19e63e8          0           1            1            1
#
#     dependency edjefe edjefa  meaneduc  instlevel1  instlevel2  instlevel3  \
# ...

# %% [markdown]
# ######  i.) Correcting Total People (hogar_total)
#
# Based on a house with only one adult, it look like hogar_total should also count of the head of the house.

# %%
df[df.idhogar=='21eb7fcc1'].iloc[:,94:114]
# Out:
#    parentesco12    idhogar  hogar_nin  hogar_adul  hogar_mayor  hogar_total  \
# 0             0  21eb7fcc1          0           1            0            1
#
#   dependency edjefe edjefa  meaneduc  instlevel1  instlevel2  instlevel3  \
# 0         no     10     no      10.0           0           0           0
#
#    instlevel4  instlevel5  instlevel6  instlevel7  instlevel8  instlevel9  \
# 0           1           0           0           0           0           0
#
#    bedrooms
# 0         1

# %%
df['new_hogar_total'] = df.apply(lambda row: (row.hogar_nin+row.hogar_adul+row.hogar_mayor), axis=1)
df.iloc[:,90:100].tail(15)
# Out:
#       parentesco8  parentesco9  parentesco10  parentesco11  parentesco12  \
# 9542            0            0             0             0             0
# 9543            0            0             0             0             0
# 9544            0            0             0             0             0
# 9545            0            0             0             0             0
# 9546            0            0             0             0             0
# 9547            0            0             0             0             0
# 9548            0            0             0             0             0
# 9549            0            0             0             0             0
# 9550            0            0             0             0             0
# 9551            0            0             0             0             0
# 9552            0            0             0             0             0
# 9553            0            0             0             0             0
# ...

# %% [markdown]
# ###### ii.) Identifying Homes With No Adults (hogar_adul)

# %% [markdown]
# I found a few houses with no hogar_mayor. These indicate that there houses where there are no parents and the
# ones that are boss of the house. I chose to remove these entries because I would not be able to recalculate the
# dependency correctly.

# %%
df[df.hogar_adul ==0].iloc[:,94:114]
#96-100
# Out:
#       parentesco12    idhogar  hogar_nin  hogar_adul  hogar_mayor  \
# 1291             0  1b31fd159          1           0            0
# 1840             0  a874b7ce7          2           0            0
# 1841             0  a874b7ce7          2           0            0
# 2049             0  faaebf71a          2           0            0
# 2050             1  faaebf71a          2           0            0
#
#       hogar_total dependency edjefe edjefa  meaneduc  instlevel1  instlevel2  \
# 1291            1          8     no     10       NaN           0           0
# 1840            2          8      4     no       NaN           0           0
# 1841            2          8      4     no       NaN           0           1
# 2049            2          8     12     no       NaN           0           0
# 2050            2          8     12     no       NaN           0           0
#
#       instlevel3  instlevel4  instlevel5  instlevel6  instlevel7  instlevel8  \
# ...

# %%
df = df[df.hogar_adul !=0]

# %% [markdown]
# ###### iii.) Correcting Depedency (dependency)
# If one also looks to the dependency ratios from codes provided above, it is evident that the definition of dependecy are not aligned to what has been applied above. As such, I will correct it.

# %%
df.loc[:,'new_dependency'] = df.apply(lambda row: ((row.hogar_nin+ row.hogar_mayor + 1)/row.hogar_adul), axis=1, )

# %%
#Find method to say that if edjefe has a number then make a new column with the value of one else put in 0

#df = df[df.dependency != "yes"]
#df['dependency'] = df['dependency'].str.replace('no', '0', regex=True)
#df['dependency'].unique() #Checking for conversion of yes to 1

# %% [markdown]
# ##### iv.) Working with Missing Values
# When checking for the number of missing values and ratio of missing variable, I found the following:
#     - rez_esc, v18q1, v2a1 mises >70% absent.
#     - Noticed the number of tablets a house own (v18q1) does not reflect 0 and could be represented as N/A
#     - Removed rez_esc and v2a1 variables since no easy method for recovering data and explanation for
#     this missing data

# %%
print(df['v18q1'].unique())
print(df['rez_esc'].unique())
print(df['v2a1'].unique())
# Out:
# [nan  1.  2.  3.  4.  5.  6.]
# [nan  1.  0.  3.  2.  4.  5.]
# [ 190000.  135000.      nan  180000.  130000.  100000.   90000.  215000.
#   150000.  120000.   80000.  168000.   40000.  155000.  200000.  350000.
#   270000.  300000.  250000.  260000.  564834.  175000.   25310.  400000.
#   450000.  399378.  119813.  125518.  125000.   60000.   35000.  160000.
#   170000.  500000.  230000.  185000.  220000.  570540.  342324.       0.
#   127000.   52000.  240000.  278000.   70000.  110000.  100297.  210000.
#   770229.  285270.  145000.   96000.  542013.   65000.   85000.  104000.
#   275000.  140000.  280000.  105661.   20000.   16000.   55000.   30000.
#   283000.  245000.  191500.  510000.   36350.   89000.  600000.   75000.
#    50000.   84529.  550000.  132000.  470000.   27000.  176000.  205000.
#   380000.  855810.  427905.  290975.  188000.  118097.  360000.  325000.
#  1000000.  700000.  288750.  219087.   95000.   93000.  800000.  456432.
# ...

# %%
print ("\nMissing values :  ", df.isnull().sum().values.sum())
# Out:
# Missing values :   22119

# %%
print('Number of absent targets by column')
print("---------------------------")
print(df.isnull().sum().sort_values(ascending=False)[0:10])
print('\n')
print('Percentage of absent targets by column')
print("-----------------------------")
print(((df.isnull() | df.isna()).sum() * 100 / df.index.size).sort_values(ascending=False).round(2)[0:10])
# Out:
# Number of absent targets by column
# ---------------------------
# rez_esc       7923
# v18q1         7337
# v2a1          6859
# public           0
# sanitario3       0
# sanitario2       0
# sanitario1       0
# coopele          0
# noelec           0
# planpri          0
# dtype: int64
#
#
# Percentage of absent targets by column
# -----------------------------
# rez_esc       82.95
# v18q1         76.81
# v2a1          71.81
# public         0.00
# sanitario3     0.00
# sanitario2     0.00
# sanitario1     0.00
# coopele        0.00
# noelec         0.00
# planpri        0.00
# dtype: float64

# %%
df['v18q1'].fillna(0, inplace=True)

df.drop(['rez_esc','v2a1'], axis=1, inplace=True)

# %% [markdown]
# ### b.) Dropping Redundant Data
#     These variables as highly correlated to their non squared variables

# %%
df.drop(['SQBescolari','SQBage','SQBhogar_total','SQBedjefe','SQBhogar_nin','SQBovercrowding','SQBdependency', 'SQBmeaned', 'agesq'], axis=1, inplace=True)

# %% [markdown]
# # 2.) Feature Engineering

# %% [markdown]
# #### i.) Extracting Gender of Headhousehold and Highest Education
# Upon selecting some variables of interest, I found the following:
#     - edjefe & edjefa: presents who the gender of the head of the household by expressing only his/her highest education and writing no.
#
# This mixture of information needs to be separated to explore more indepth

# %%
df[['idhogar', 'Id', 'edjefe', 'edjefa', 'parentesco1', 'meaneduc', 'male', 'female']].head(10)
# Out:
#      idhogar            Id edjefe edjefa  parentesco1  meaneduc  male  female
# 0  21eb7fcc1  ID_279628684     10     no            1      10.0     1       0
# 1  0e5d7a658  ID_f29eb3ddd     12     no            1      12.0     1       0
# 2  2c7317ea8  ID_68de51c94     no     11            1      11.0     0       1
# 3  2b58d945f  ID_d671db89c     11     no            0      11.0     1       0
# 4  2b58d945f  ID_d56d6f5f5     11     no            0      11.0     0       1
# 5  2b58d945f  ID_ec05b1a7b     11     no            1      11.0     1       0
# 6  2b58d945f  ID_e9e0c1100     11     no            0      11.0     0       1
# 7  d6dae86b7  ID_3e04e571e      9     no            0      10.0     0       1
# 8  d6dae86b7  ID_1284f8aad      9     no            1      10.0     1       0
# 9  d6dae86b7  ID_51f52fdd2      9     no            0      10.0     0       1

# %% [markdown]
# #### ii.) Create a column for the gender of the head household
# Will create a column that will have male or female for the head of the household. For any houses that do not
# identify this will be left as unknown

# %%
conditions = [
    (df['edjefe'] != 'no') & (df['edjefe'] != 'yes'),
    (df['edjefa'] != 'no') & (df['edjefa'] != 'yes'),
    (df['edjefe'] == 'yes') & (df['edjefe'] == 'no'),
    (df['edjefe'] == 'yes') & (df['edjefe'] == 'no'),]
choices = ['male', 'female','male', 'female']
df['HeadhouseGender'] = np.select(conditions, choices, default='unknown')

# %% [markdown]
# #### iii.) Create a column for the highest level of education by head of household
# Will create a column reflecting the highest education of the mother or father (whoever is the head of the household)

# %%
df.loc[(df['edjefe'] == 'no'), 'edjefe'] = df['edjefa']
df = df[df.edjefe != "yes"]
df = df[df.edjefe != "no"]
df.rename(columns = {'edjefe':'HeadhouseholdEducation'}, inplace = True)

# %%
df.drop('edjefa',axis=1,inplace=True)

# %%
df.HeadhouseholdEducation = df.HeadhouseholdEducation.apply(int)

# %% [markdown]
# #### iv.) Dropping Duplicate Individual Id

# %%
df[df.Id.duplicated() == True]
df.drop('Id',axis=1,inplace=True)
df.dropna(inplace=True) #originally missed on 5 values from the [50:100] and [100:150]
print ("\nMissing values :  ", df.isnull().sum().values.sum())
# Out:
# Missing values :   0

# %% [markdown]
# # 3.) Addressing Wrong Labels
#
# Some of the labels are not correct because individuals in the same household have a different poverty level. We're not told why this may be the case, but we are told to use the head of household as the true label.
#
# #### i.) Identify Errors
#
# First we need to find the errors before we can correct them. To find the households with different labels for family members, we can group the data by the household and then check if there is only one unique value of the Target.

# %%
# Groupby the household and figure out the number of unique values
all_equal = df.groupby('idhogar')['Target'].apply(lambda x: x.nunique() == 1)

# Households where targets are not all equal
not_equal = all_equal[all_equal != True]

print('There are {} households where the family members do not all have the same target.'.format(len(not_equal)))
# Out:
# There are 75 households where the family members do not all have the same target.

# %%
df[df['idhogar'] == not_equal.index[0]][['idhogar', 'parentesco1', 'Target']]
# Out:
#         idhogar  parentesco1  Target
# 7651  0172ab1d9            0       3
# 7652  0172ab1d9            0       2
# 7653  0172ab1d9            0       3
# 7654  0172ab1d9            1       3
# 7655  0172ab1d9            0       2

# %% [markdown]
# The organizers tell us that the correct label is that for the head of household, where parentesco1 == 1. For this household, the correct label is 3 for all members. We can correct this (as shown later) by reassigning all the individuals in this household the correct poverty level.

# %% [markdown]
# #### ii.) Families without Heads of Household
#
# We can correct all the label discrepancies by assigning the individuals in the same household the label of the head of household. But wait, you may ask: "What if there are households without a head of household? And what if the members of those households have differing values of the label?"
#
# Well, since you asked, let's investigate exactly that question!

# %%
households_leader = df.groupby('idhogar')['parentesco1'].sum()

# Find households without a head
households_no_head = df.loc[df['idhogar'].isin(households_leader[households_leader == 0].index), :]

print('There are {} households without a head.'.format(households_no_head['idhogar'].nunique()))
# Out:
# There are 15 households without a head.

# %%
# Find households without a head and where labels are different
households_no_head_equal = households_no_head.groupby('idhogar')['Target'].apply(lambda x: x.nunique() == 1)
print('{} Households with no head have different labels.'.format(sum(households_no_head_equal == False)))
# Out:
# 0 Households with no head have different labels.

# %% [markdown]
# Well that's a relief! This means that we don't have to worry about a household both where there is no head AND the members have different values of the label! For this problem, according to the organizers, if a household does not have a head, then there is no true label. Therefore, we actually won't use any of the households without a head for training.

# %% [markdown]
# #### iii.) Correct Errors
#
# Now we can correct labels for the households that do have a head AND the members have different poverty levels.

# %%
# Iterate through each household
for household in not_equal.index:
    # Find the correct label (for the head of household)
    true_target = int(df[(df['idhogar'] == household) & (df['parentesco1'] == 1.0)]['Target'])
    
    # Set the correct label for all members in the household
    df.loc[df['idhogar'] == household, 'Target'] = true_target
    
    
# Groupby the household and figure out the number of unique values
all_equal = df.groupby('idhogar')['Target'].apply(lambda x: x.nunique() == 1)

# Households where targets are not all equal
not_equal = all_equal[all_equal != True]
print('There are {} households where the family members do not all have the same target.'.format(len(not_equal)))
# Out:
# There are 0 households where the family members do not all have the same target.

# %% [markdown]
# # 4.) Data Analysis

# %% [markdown]
# ### a.) Working with One-hot Encoded :
#     Before proceeding with data analysis, I need to fix columns since it would be hard for digestable visualization

# %%
df['Place'] = (df[['lugar1','lugar2','lugar3','lugar4','lugar5','lugar6']] == 1).idxmax(1)
df['Education'] =  (df[['instlevel1','instlevel2','instlevel3','instlevel4','instlevel5','instlevel6','instlevel7','instlevel8','instlevel9']] == 1).idxmax(1)
df['TypeofHome']= (df[['tipovivi1','tipovivi2','tipovivi3','tipovivi4','tipovivi5']]== 1).idxmax(axis=1)
df['WallType']= (df[['paredblolad', 'paredzocalo','paredpreb','pareddes','paredmad','paredzinc','paredfibras','paredother']]== 1).idxmax(axis=1)
df['FloorType'] = (df[['pisomoscer','pisocemento','pisoother', 'pisonatur', 'pisonotiene','pisomadera']]== 1).idxmax(axis=1)
df['RoofType']= (df[['techozinc', 'techoentrepiso','techocane',  'techootro']]== 1).idxmax(axis=1)
df['WaterSource'] = (df[['abastaguadentro','abastaguafuera', 'abastaguano']]== 1).idxmax(axis=1)
df['Sanitary'] = (df[['sanitario1', 'sanitario2', 'sanitario3', 'sanitario5', 'sanitario6']]== 1).idxmax(axis=1)
df['EnergySource'] = (df[['energcocinar1','energcocinar2', 'energcocinar3', 'energcocinar4']]== 1).idxmax(axis=1)
df['RubishDisposalMethod'] = (df[['elimbasu1', 'elimbasu2', 'elimbasu3', 'elimbasu4', 'elimbasu5', 'elimbasu6']]== 1).idxmax(axis=1)
df['ToiletType'] = (df[['sanitario1', 'sanitario2', 'sanitario3', 'sanitario5', 'sanitario6']]== 1).idxmax(axis=1)
df['Area'] = (df[['area1', 'area2']]== 1).idxmax(axis=1)

# Must be 0, 1, 2

df['WallRate'] = (df[['epared1', 'epared2', 'epared3']]== 1).idxmax(axis=1)
df['CeilingRate'] = (df[['etecho1', 'etecho2', 'etecho3']]== 1).idxmax(axis=1)
df['FloorRate'] = (df[['eviv1', 'eviv2', 'eviv3']]== 1).idxmax(axis=1)

# %% [markdown]
# ### b.) Target Distribution
# Explored the distribution of poverty within Costa Rica, our target value:
#         - Non-vulnerable cases make up 64.76 % of all cases.
#         - Moderate poverty cases make up 15.91 % of all cases.
#         - Vulnerable poverty cases make up 12.02 % of all cases.
#         - Extreme poverty cases make up 7.31 % of all cases.

# %%
mapped = {1: 'extreme poverty', 2:'moderate poverty', 3: 'vulnerable', 4: 'non_vulnerable'}
df['TargetCateg'] = df['Target']
df.TargetCateg = df.TargetCateg.replace(mapped)

df['TargetCateg'].value_counts().plot(kind = 'barh', grid = True, color= "purple", edgecolor='black', figsize=(15,8))
plt.ylabel("Poverty Level")
plt.xlabel("Value Counts")
plt.title("Value Counts for Poverty in Costa Rica")
# Out:
# Text(0.5,1,'Value Counts for Poverty in Costa Rica')

# %%
print("Non-vulnerable cases make up", round((df.TargetCateg.value_counts()[0] / df.shape[0]) * 100, 2), "% of all cases.")
print("Moderate poverty cases make up", round((df.TargetCateg.value_counts()[1] / df.shape[0]) * 100, 2), "% of all cases.")
print("Vulnerable poverty cases make up", round((df.TargetCateg.value_counts()[2] / df.shape[0]) * 100, 2), "% of all cases.")
print("Extreme poverty cases make up", round((df.TargetCateg.value_counts()[3] / df.shape[0]) * 100, 2), "% of all cases.")
# Out:
# Non-vulnerable cases make up 64.84 % of all cases.
# Moderate poverty cases make up 15.51 % of all cases.
# Vulnerable poverty cases make up 12.17 % of all cases.
# Extreme poverty cases make up 7.48 % of all cases.

# %% [markdown]
# ### c.) Exploring Gender:
#
# - Generally, females have slightly higher chances of being in a position of poverty than men

# %%
#Replace numbers with each person's gender
gender_map = {1: 'Female', 0: 'Male'}
df['Gender'] = df.female.replace(gender_map)
df.drop(['female'], axis=1, inplace=True)
df.drop(['male'], axis=1, inplace=True)

# %%
#Gender vs Levels of Poverty
sns.catplot(y="TargetCateg", hue="Gender", kind="count",
            palette="pastel", edgecolor=".6",
            data=df);

# %%
df.groupby('Gender')['TargetCateg'].value_counts()
# Out:
# Gender  TargetCateg
# Female  non_vulnerable      2917
#         moderate poverty     743
#         vulnerable           581
#         extreme poverty      386
# Male    non_vulnerable      2870
#         moderate poverty     641
#         vulnerable           505
#         extreme poverty      282
# Name: TargetCateg, dtype: int64

# %% [markdown]
# #### i.) Males vs Levels of Poverty

# %% [markdown]
# ##### a.)  Males < 12 Years vs Levels of Poverty:
# - From the data, the more children in a household, the higher levels of risk in falling in a vulnerable or poverty level.
# - Due to poor sampling of four or five families with 4 and 5 males children under the age of 12, generalizability and visualization of data is relatively difficult. However, we can still see a trend of the impact of having more children in a household to levels of poverty. The next figure groups shows this pattern more strongly. The figure groups three, four, five, under three to show more of a pattern.

# %%
sns.catplot(y="r4h1", hue="TargetCateg", kind="count",
            palette="RdBu_r", edgecolor=".6",
            data=df);

df.groupby('r4h1')['TargetCateg'].value_counts(True).reindex(['non_vulnerable','vulnerable','moderate poverty','extreme poverty'], level=1).unstack(1).sort_values('r4h1').plot.barh(stacked= True, figsize=(15,8))

# %% [markdown]
# ###### Balance:
# - From this adjusted figure we can see a clear trend that the more kids that less than 12 years old, there is a higher chance of falling outside of a non-vulnerable group. In fact, we can note that the seveity of poverty also increases as the number of children that less than 12 years old increases.

# %%
df_temp = df 
df_temp[['r4h1']] = df_temp[['r4h1']].replace([3,4,5], 3)

sns.catplot(y="r4h1", hue="TargetCateg", kind="count",
            palette="RdBu_r", edgecolor=".6",
            data=df_temp);

df_temp.groupby('r4h1')['TargetCateg'].value_counts(True).reindex(['non_vulnerable','vulnerable','moderate poverty','extreme poverty'], level=1).unstack(1).sort_values('r4h1').plot.barh(stacked= True, figsize=(15,8))

# %% [markdown]
# ##### b.)  Males > 12 Years vs Levels of Poverty:
# - From the data, the more children older than 12 in a household, the lower the risk in falling in a vulnerable or poverty level up until 5. This could be explained by the distribution of age within the sample. Something that will be explored more.
# - Due to poor sampling of families with 6,7, and 8 males children older than the age of 12, generalizability and visualization of data for these spectrum is relatively difficult. The next figure groups five, six, seven under 5 to show more of a pattern.

# %%
sns.catplot(y="r4h2", hue="TargetCateg", kind="count",
            palette="RdBu_r", edgecolor=".6",
            data=df);

df.groupby('r4h2')['TargetCateg'].value_counts(True).reindex(['non_vulnerable','vulnerable','moderate poverty','extreme poverty'], level=1).unstack(1).sort_values('r4h2').plot.barh(stacked= True, figsize=(15,8))

# %% [markdown]
# ###### Balance:
# - From this adjusted figure we can see a clear trend that the more males that are older than 12 years old, decreases the chance of up until 3, then we start seeing the chances of falling outside a non-vulnerable group increasse. In fact, we can note that the severity of poverty also decreases as the number of males that older than 12 years old increases.

# %%
df_temp = df 
df_temp[['r4h2']] = df_temp[['r4h2']].replace([5,6,7,8], 5)

sns.catplot(y="r4h2", hue="TargetCateg", kind="count",
            palette="RdBu_r", edgecolor=".6",
            data=df_temp);

df_temp.groupby('r4h2')['TargetCateg'].value_counts(True).reindex(['non_vulnerable','vulnerable','moderate poverty','extreme poverty'], level=1).unstack(1).sort_values('r4h2').plot.barh(stacked= True, figsize=(15,8))

# %% [markdown]
# ##### c.) Total Males:
# - From the data, it shows the presense of a few male seems to find themselves with non-vulnerable positions.
# - Due to poor sampling of families with 6,7, and 8 males, accurate interpretability and visualization for this spectrum is relatively difficult. However, we can still see a trend.
# - It is worth noting that from previous male analysis, this is the composition of males less than 12 and older than 12, so processing this graph must consider both in mind.

# %%
sns.catplot(y="r4h3", hue="TargetCateg", kind="count",
            palette="RdBu_r", edgecolor=".6",
            data=df);

df.groupby('r4h3')['TargetCateg'].value_counts(True).reindex(['non_vulnerable','vulnerable','moderate poverty','extreme poverty'], level=1).unstack(1).sort_values('r4h3').plot.barh(stacked= True, figsize=(15,8))

# %% [markdown]
# ###### Balance:
# - From this adjusted figure we can see a clear trend that the more kids that less than 12 years old, there is a higher chance of falling outside of a non-vulnerable group. In fact, we can note that the seveity of poverty also increases as the number of children that less than 12 years old increases.

# %%
df_temp = df 
df_temp[['r4h3']] = df_temp[['r4h3']].replace([5,6,7,8], 5)

sns.catplot(y="r4h3", hue="TargetCateg", kind="count",
            palette="RdBu_r", edgecolor=".6",
            data=df_temp);

df_temp.groupby('r4h3')['TargetCateg'].value_counts(True).reindex(['non_vulnerable','vulnerable','moderate poverty','extreme poverty'], level=1).unstack(1).sort_values('r4h3').plot.barh(stacked= True, figsize=(15,8))

# %% [markdown]
# #### i.) Females vs Levels of Poverty

# %% [markdown]
# ##### a.) Females < 12 Years vs Levels of Poverty:
# - The more female less than 12 years old in a household, the morelikely to be in a position of poverty or vulnerability. Based on this data, this is the most telling of the many graphs.
# - It is important to note there is not strong visibility of 5 females less than 12 in a household in this sample
# - The next figure groups three, four, and six under three to show more of a pattern.

# %%
sns.catplot(y="r4m1", hue="TargetCateg", kind="count",
            palette="RdBu_r", edgecolor=".6",
            data=df);


df.groupby('r4m1')['TargetCateg'].value_counts(True).reindex(['non_vulnerable','vulnerable','moderate poverty','extreme poverty'], level=1).unstack(1).sort_values('r4m1').plot.barh(stacked= True, figsize=(15,8))

# %% [markdown]
# ###### Balance:
#
# - From this adjusted figure we can see a clear trend that the more females less than 12 years old, the higher the rate of falling outside of a non-vulnerable group.  In fact, we can note that the severity of poverty also increases as the number of female that younger than 12 years old increases.

# %%
df_temp = df 
df_temp[['r4m1']] = df_temp[['r4m1']].replace([3,4,6], 3)

sns.catplot(y="r4m1", hue="TargetCateg", kind="count",
            palette="RdBu_r", edgecolor=".6",
            data=df_temp);


df.groupby('r4m1')['TargetCateg'].value_counts(True).reindex(['non_vulnerable','vulnerable','moderate poverty','extreme poverty'], level=1).unstack(1).sort_values('r4m1').plot.barh(stacked= True, figsize=(15,8))

# %% [markdown]
# ##### b.) Females > 12 Years vs Levels of Poverty:
#
# - Though a little bit unclearly, the more women that are older than 12 in a household, the more likely they are to be in a vulnerable or poverty level. These females tend to be in a position of more being in a non-vulnerable position than females that are younger than 12.

# %%
sns.catplot(y="r4m2", hue="TargetCateg", kind="count",
            palette="RdBu_r", edgecolor=".6",
            data=df);


df.groupby('r4m2')['TargetCateg'].value_counts(True).reindex(['non_vulnerable','vulnerable','moderate poverty','extreme poverty'], level=1).unstack(1).sort_values('r4m2').plot.barh(stacked= True, figsize=(15,8))

# %% [markdown]
# ###### Balance:
#
# - From this adjusted figure we can see a clear trend that the more females older than 12 years old, the higher the rate of falling outside of a non-vulnerable group.  In fact, we can note that the severity of poverty also increases as the number of female that older than 12 years old increases. This is the same idea for females younger than 12 years old except less severe.

# %%
df_temp = df 
df_temp[['r4m2']] = df_temp[['r4m2']].replace([3,4,5,6], 3)

sns.catplot(y="r4m2", hue="TargetCateg", kind="count",
            palette="RdBu_r", edgecolor=".6",
            data=df_temp);


df_temp.groupby('r4m2')['TargetCateg'].value_counts(True).reindex(['non_vulnerable','vulnerable','moderate poverty','extreme poverty'], level=1).unstack(1).sort_values('r4m2').plot.barh(stacked= True, figsize=(15,8))

# %% [markdown]
# ##### c.) Total Females vs Levels of Poverty
# - Overall these statistics confirm the previous finding that the more women in a household, the more higher the chances of finding themselves in a vulnurable or poverty level
# - The section balanced will group 5,6,7,8 into 5 to visualization easier.

# %%
sns.catplot(y="r4m3", hue="TargetCateg", kind="count",
            palette="RdBu_r", edgecolor=".6",
            data=df);


df.groupby('r4m3')['TargetCateg'].value_counts(True).reindex(['non_vulnerable','vulnerable','moderate poverty','extreme poverty'], level=1).unstack(1).sort_values('r4m3').plot.barh(stacked= True, figsize=(15,8))

# %% [markdown]
# ###### Balance:
#
# - From this adjusted figure we can see a clear trend that the more females, the higher the rate of falling outside of a non-vulnerable group.  In fact, we can note that the severity of poverty also increases as the number of female increases.

# %%
df_temp = df 
df_temp[['r4m3']] = df_temp[['r4m3']].replace([5,6,7,8], 5)

sns.catplot(y="r4m3", hue="TargetCateg", kind="count",
            palette="RdBu_r", edgecolor=".6",
            data=df);


df.groupby('r4m3')['TargetCateg'].value_counts(True).reindex(['non_vulnerable','vulnerable','moderate poverty','extreme poverty'], level=1).unstack(1).sort_values('r4m3').plot.barh(stacked= True, figsize=(15,8))

# %% [markdown]
# #### ii.) Total Persons vs Levels of Poverty
# - The more people in a household, the stronger association that they will fall in a falling in a poverty or vulnerable level. In fact the more people, the higher the chances there are to falling in a more severe category.

# %%
sns.catplot(y="r4t3", hue="TargetCateg", kind="count",
            palette="RdBu_r", edgecolor=".6",
            data=df);

df.groupby('r4t3')['TargetCateg'].value_counts(True).reindex(['non_vulnerable','vulnerable','moderate poverty','extreme poverty'], level=1).unstack(1).sort_values('r4t3').plot.barh(stacked= True, figsize=(15,8))

# %% [markdown]
# ###### Balance:
#
# - From this adjusted figure we can see a clear trend that the more family members in a house, the higher the rate of falling outside of a non-vulnerable group.  In fact, we can note that the severity of poverty also increases as the number of members increases.

# %%
df_temp = df 
df_temp[['r4t3']] = df_temp[['r4t3']].replace([8,9,10,11,12], 8)


sns.catplot(y="r4t3", hue="TargetCateg", kind="count",
            palette="RdBu_r", edgecolor=".6",
            data=df);

df.groupby('r4t3')['TargetCateg'].value_counts(True).reindex(['non_vulnerable','vulnerable','moderate poverty','extreme poverty'], level=1).unstack(1).sort_values('r4t3').plot.barh(stacked= True, figsize=(15,8))

# %% [markdown]
# #### iii.) Children, Parents, Elderly, and Total Members vs Poverty Levels
#     - For children, the more kids in a household, the more likely to be in vulnerable or poverty level
#     - In fact the more people, the higher the chances there are to falling in a more severe category
#     - The more adults, the more likely to be in a non-vulnerable group until 6+
#     - For number of kids in a home (hogar_nin), we grouped 5,6,7,8 as 5+
#     - For number of adults in a home (hogar_adul), we grouped 7,8,9 as 7+
#     - For number of people in a home (hogar_total), we grouped 9,10,11,12 as 9+

# %%
df_temp = df 
df_temp[['hogar_nin']] = df_temp[['hogar_nin']].replace([5,6,7,8], 5)

sns.catplot(y="hogar_nin", hue="TargetCateg", kind="count",
            palette="RdBu_r", edgecolor=".6", height=8.27, aspect=11.7/8.27,
            data=df);
df.groupby('hogar_nin')['TargetCateg'].value_counts(True).reindex(['non_vulnerable','vulnerable','moderate poverty','extreme poverty'], level=1).unstack(1).sort_values('hogar_nin').plot.barh(stacked= True, figsize=(15,8))

##

df_temp[['hogar_adul']] = df_temp[['hogar_adul']].replace([7,8,9], 7)

sns.catplot(y="hogar_adul", hue="TargetCateg", kind="count",
            palette="RdBu_r", edgecolor=".6", height=8.27, aspect=11.7/8.27,
            data=df);

df.groupby('hogar_adul')['TargetCateg'].value_counts(True).reindex(['non_vulnerable','vulnerable','moderate poverty','extreme poverty'], level=1).unstack(1).sort_values('hogar_adul').plot.barh(stacked= True, figsize=(15,8))

##

sns.catplot(y="hogar_mayor", hue="TargetCateg", kind="count",
            palette="RdBu_r", edgecolor=".6", height=8.27, aspect=11.7/8.27,
            data=df);
df.groupby('hogar_mayor')['TargetCateg'].value_counts(True).reindex(['non_vulnerable','vulnerable','moderate poverty','extreme poverty'], level=1).unstack(1).sort_values('hogar_mayor').plot.barh(stacked= True, figsize=(15,8))

##

df_temp[['hogar_total']] = df_temp[['hogar_total']].replace([9,10,11,12], 9)

sns.catplot(y="hogar_total", hue="TargetCateg", kind="count",
            palette="RdBu_r", edgecolor=".6", height=8.27, aspect=11.7/8.27,
            data=df);
df.groupby('hogar_total')['TargetCateg'].value_counts(True).reindex(['non_vulnerable','vulnerable','moderate poverty','extreme poverty'], level=1).unstack(1).sort_values('hogar_total').plot.barh(stacked= True, figsize=(15,8))

# %% [markdown]
# ### d.) Exploring Characteristics of Home:

# %% [markdown]
# #### i.) Distribution of Places:
# From the data, there is a largest representation of Lugar1. This can potentially become an issue when trying to find a method of modeling poverty in Costa Rica if the model caters to features found in Lugar1.

# %%
sns.countplot(x="Place", color = 'purple', linewidth=5,  data=df)

# %% [markdown]
# When looking at the different places, it seems they all average around 3. We may potentially consider Lugar3, Lugar4, and Lugar5 to be deviating away from Lugar1, Lugar2, and Lugar6.

# %%
df.groupby("Place")["Target"].mean().plot(x='Place', kind = 'bar', color= 'purple',figsize=(10,5))
df.groupby("Place")["Target"].mean()
# Out:
# Place
# lugar1    3.479940
# lugar2    3.285199
# lugar3    3.000000
# lugar4    3.069293
# lugar5    3.086691
# lugar6    3.225266
# Name: Target, dtype: float64

# %% [markdown]
# #### ii.) Location of Place vs Target Levels:

# %%
sns.catplot(y="Place", hue="TargetCateg", kind="count",
            palette="RdBu_r", edgecolor=".6", height=8.27, aspect=11.7/8.27,
            data=df);

df.groupby('Place')['TargetCateg'].value_counts(True).reindex(['non_vulnerable','vulnerable','moderate poverty','extreme poverty'], level=1).reindex(['non_vulnerable','vulnerable','moderate poverty','extreme poverty'], level=1).unstack(1).sort_values('Place').plot.barh(stacked= True, figsize=(15,8))

# %% [markdown]
# ### Utilities of the Home:

# %%
for variable in ['TypeofHome', 'WallType', 'FloorType' , 'RoofType', 'WaterSource', 'Sanitary', 'EnergySource', 'RubishDisposalMethod', 'ToiletType']:
    sns.catplot(y=variable, hue="TargetCateg", kind="count",
            palette="RdBu_r", edgecolor=".6", height=8.27, aspect=11.7/8.27,
            data=df);
    df.groupby(variable)['TargetCateg'].value_counts(True).reindex(['non_vulnerable','vulnerable','moderate poverty','extreme poverty'], level=1).reindex(['non_vulnerable','vulnerable','moderate poverty','extreme poverty'], level=1).unstack(1).sort_values(variable).plot.barh(stacked= True, figsize=(15,8))

# %% [markdown]
# #### vi.) Exploring Education, Dependency, and Tablets

# %%
from collections import OrderedDict

plt.figure(figsize = (20, 16))

# Color mapping
colors = OrderedDict({1: 'red', 2: 'orange', 3: 'blue', 4: 'green'})
poverty_mapping = OrderedDict({1: 'extreme', 2: 'moderate', 3: 'vulnerable', 4: 'non vulnerable'})

plt.figure(figsize = (16, 12))
# Iterate through the float columns
for i, col in enumerate(['HeadhouseholdEducation','meaneduc','new_dependency','age']):
    ax = plt.subplot(5, 1, i + 1)
    # Iterate through the poverty levels
    for poverty_level, color in colors.items():
        # Plot each poverty level as a separate line
        sns.kdeplot(df.loc[df['Target'] == poverty_level, col].dropna(), 
                    ax = ax, color = color, label = poverty_mapping[poverty_level])
        
    plt.title(f'{col.capitalize()} Distribution'); plt.xlabel(f'{col}'); plt.ylabel('Density')

plt.subplots_adjust(top = 2)
#for i, col in enumerate(df.select_dtypes('float')):
# Out:
# /anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### vii.) Exploring Information of Households

# %%
plt.figure(figsize = (16, 12))
# Iterate through the float columns
for i, col in enumerate(['rooms', 'tamhog','tamviv','hhsize','bedrooms','overcrowding','new_hogar_total']):
    ax = plt.subplot(4, 2, i + 1)
    # Iterate through the poverty levels
    for poverty_level, color in colors.items():
        # Plot each poverty level as a separate line
        sns.kdeplot(df.loc[df['Target'] == poverty_level, col].dropna(), 
                    ax = ax, color = color, label = poverty_mapping[poverty_level])
        
    plt.title(f'{col.capitalize()} Distribution'); plt.xlabel(f'{col}'); plt.ylabel('Density')

plt.subplots_adjust(top = 2)
# Out:
# /anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.relplot(x="new_dependency", y="meaneduc", hue="TargetCateg", height=9.5, aspect=1.5, data=df);

# %%
sns.relplot(x="meaneduc", y="overcrowding", hue="TargetCateg", height=9, aspect=1.5, data=df);

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.violinplot(x = 'v18q1', y = 'new_dependency', hue = 'TargetCateg', width = .8, data = df)
# Out:
# /anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df_temp = df 
df_temp[['v18q1']] = df_temp[['v18q1']].replace([2,3,4,5,6], 2)

sns.set(rc={'figure.figsize':(11.7,8.27)})


sns.violinplot(x = 'v18q1', y = 'new_dependency', hue = 'TargetCateg', width = .8, data = df_temp)
# Out:
# /anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.violinplot(x = 'v18q1', y = 'meaneduc', hue = 'TargetCateg', width = .8, data = df)
# Out:
# /anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.violinplot(x="v18q1", y="meaneduc", hue="TargetCateg", data=df_temp);
# Out:
# /anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.violinplot(x = 'qmobilephone', y = 'meaneduc', hue = 'TargetCateg', width = .8, data = df)
# Out:
# /anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df_temp = df 
df_temp[['qmobilephone']] = df_temp[['qmobilephone']].replace([5,6,7,8,9,10], 5)
sns.violinplot(x = 'qmobilephone', y = 'new_dependency', hue = 'TargetCateg', width = .8, data = df)
# Out:
# /anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df_temp = df 
df_temp[['qmobilephone']] = df_temp[['qmobilephone']].replace([5,6,7,8,9,10], 5)
sns.violinplot(x = 'qmobilephone', y = 'meaneduc', hue = 'TargetCateg', width = .8, data = df)
# Out:
# /anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
from statsmodels.graphics.mosaicplot import mosaic
import matplotlib.pyplot as plt
import seaborn as sns
 
mosaic(df, ['Area', 'TargetCateg', 'Place'], properties = lambda key: {'color': 'r' if 'a' in key else 'orange'}, label_rotation=0.0, gap=.05,)
plt.show()

# %%
mosaic(df, ['TargetCateg', 'FloorRate', 'TypeofHome'], properties = lambda key: {'color': 'r' if 'eviv1' in key else 'orange'}, label_rotation=0.0, gap=.01)
plt.show()

# %%
df.to_csv("all/corrected_train.csv")
